# %%
import execjs
import requests


with open('./js_data.js', 'r', encoding='utf-8') as f:
    js = execjs.compile(f.read())

i0x = {'rid': 'R_SO_4_1852762860',
       'threadId': 'R_SO_4_1852762860',
       'pageNo': '1',
       'pageSize': '20',
       'cursor': '-1',
       'offset': '0',
       'orderType': '1',
       'csrf_token': ''};

dict_data = js.call('get_data', i0x)
print(dict_data)
print()

response = requests.post('https://music.163.com/weapi/comment/resource/comments/get',
                         data=dict_data)
print(response)
print()

dict_ = response.json()

list_comment = dict_['data']['comments']
for i, comment in enumerate(list_comment):
    print(f'''{i + 1}. {comment['content'].strip()}''')
print()

cursor = dict_['data']['cursor']
print(cursor)
print()

dict_data = js.call('get_data', {**i0x, 'cursor': cursor})
print(dict_data)
print()

response = requests.post('https://music.163.com/weapi/comment/resource/comments/get',
                         data=dict_data)
print(response)
print()

dict_ = response.json()

list_comment = dict_['data']['comments']
for i, comment in enumerate(list_comment):
    print(f'''{i + 1}. {comment['content'].strip()}''')
print()
# Out:
# {'params': '', 'encSecKey': ''}
#
# <Response [200]>
#
# 1. ly；早安
# 2. 2025年，是不是人都不在了，也不出来冒泡了
# 3. 吧
# 4. 今天是2025年的7月27号 离日出还有7小时54分钟
# 5. 2025年了，还在听[大笑]
# 6. 甾::了: 刁钻乙:
# ;:了: 丿刀:02053
# 39
# 7. 买什么车啊 直接买孙露
# 8. 0
# 9. 人口买卖是违法的，明星也不行！
# 10. 告别许多的人情世故，也将要和秋天告别，迎接冬天的到来，而在冬天来过之后，春天还会离我们远吗？
# 11. 25年了又回来找[大哭][大哭]
# 12. [YYDS][YYDS][YYDS]
# 13. 25年了还在听
# 14. 理解我爸 成为我爸 超越我爸
# 15. 当年听这首歌的时候，我和我爸两个人在县医院住院，现在他已经离开我七八年了。
# 16. 大柏林？[大哭][大哭][大哭]
# 17. 我用了很久很久，成全了你的轻松
# 18. 分手就分手，跑我庄园里揍我的鸡干吗
# 19. 我依然还在
# 20. 直接娶了孙露
#
# 1750896366057
#
# {'params': '', 'encSecKey': ''}
#
# <Response [200]>
#
# 1. 买了辆A8，听孙露的歌美滋滋
# 2. 偶然结识了一位江湖大哥，和大哥一起吃饭，发现他的右脸上有一道深深的刀疤，遂问：“大哥，你这么神勇，我想知道到底是什么人能在你的脸上留下一道如此深的刀疤？！”大哥这时放下酒杯，四十五度角仰望天花板，眼里泛着泪光，说：“我，是剖腹产……”
# 3. 偶然结识了一位江湖大哥，和大哥一起吃饭，发现他的右脸上有一道深深的刀疤，遂问：“大哥，你这么神勇，我想知道到底是什么人能在你的脸上留下一道如此深的刀疤？！”大哥这时放下酒杯，四十五度角仰望天花板，眼里泛着泪光，说：“我，是剖腹产……”
# 4. 25依然在
# 5. ...！
# 6. .的↖丨
# 7. 我讨厌你封建的思想，却又心疼你劳累的模样，讨厌你的大男子主义，又心疼你眼里布满的红血丝，我恨你的固执己见，又心疼你这些年的风霜雨雪，最讨厌你的脾气了，可偏偏我的脾气还最像你。
# 8. 25年都在听…
# 9. 越来越喜欢这样风格的歌曲了
# 10. 黄玫瑰这首歌也好听
# 11. 2025第一次听
# 12. 时间终将过去
# 13. 你喜欢秋天
# 14. 2025年
# 15. 昨天太短，明天太远。从此想你说不出口
# 16. 评论区的朋友才华横溢
# 17. 我们低估了时间的善变 才会让原本热烈的东西翻篇
# 18. 我也这样，玩手机玩的
# 19. 25年依旧
# 20. 90后有人听这首歌吗
