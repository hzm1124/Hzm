# %%
import execjs
from time import time
import requests


with open('./js_sign.js', 'r', encoding='utf-8') as f:
    js = execjs.compile(f.read())

cid = '508'
param = {'cityId': '301',
         'serialId': '11108'}
o = '19DDD1FBDFF065D3A4DA777D2D7A81EC'
timestamp = str(int(time() * 1000))

sign = js.call('get_sign', cid, param, o, timestamp)
print(sign)
print()

dict_param = {'cid': cid,
              'param': sign['json_param']}
dict_header = {'x-platform': 'pc',
               'x-sign': sign['sign'],
               'x-timestamp': timestamp}
response = requests.get('https://mhapi.yiche.com/hcar/h_car/api/v1/param/get_param_details',
                        params=dict_param,
                        headers=dict_header)
print(response.text)
print(response)
# Out:
# {'json_param': '{"cityId":"301","serialId":"11108"}', 'sign': 'f13b1adec492525098f74d5f2b65ea72'}
#
# {"status":"1","message":"success","data":{"list":[{"name":"基本信息","items":[{"id":-1,"name":"车款名称","paramValues":[{"id":178403,"value":"25款 835km 后驱标准版","baseInfoKey":"{\"masterId\":\"702\",\"serialName\":\"小米YU7\",\"serialId\":\"11108\",\"year\":\"2025\",\"serialAllSpell\":\"xiaomimx11\",\"saleStatus\":\"1\",\"masterName\":\"小米汽车\"}","subList":[{"value":"25款 835km 后驱标准版"}],"subListSize":0,"videoFlag":0,"imageFlag":0,"evaluationId":0,"evaluationItemId":0},{"id":179144,"value":"25款 770km 四驱Pro版","baseInfoKey":"{\"masterId\":\"702\",\"serialName\":\"小米YU7\",\"serialId\":\"11108\",\"year\":\"2025\",\"serialAllSpell\":\"xiaomimx11\",\"saleStatus\":\"1\",\"masterName\":\"小米汽车\"}","subList":[{"value":"25款 770km 四驱Pro版"}],"subListSize":0,"videoFlag":0,"imageFlag":0,"evaluationId":0,"evaluationItemId":0},{"id":175005,"value":"25款 760km 四驱Max版","baseInfoKey":"{\"masterId\":\"702\",\"serialName\":\"小米YU7\",\"serialId\":\"11108\",\"year\":\"2025\",\"serialAllSpell\":\"xiaomimx11\",\"saleStatus\":\"1\",\"masterName\":\"小米汽车\"}","subList":[{"value":"25款 760km 四驱Max版"}],"subListSize":0,"videoFlag":0,"imageFlag":0,"evaluationId":0,"evaluationItemId":0}],"paramId":"-1","paramType":-1,"desc":"","type":1,"sameType":2,"encyclopediaId":"","keyItem":1},{"id":-2,"name":"厂商指导价","paramValues":[{"id":178403,"value":"25.35万","subList":[{"value":"25.35万"}],"subListSize":0,"videoFlag":0,"imageFlag":0,"evaluationId":0,"evaluationItemId":0},{"id":179144,"value":"27.99万","subList":[{"value":"27.99万"}],"subListSize":0,"videoFlag":0,"imageFlag":0,"evaluationId":0,"evaluationItemId":0},{"id":175005,"value":"32.99万","subList":[{"value":"32.99万"}],"subListSize":0,"videoFlag":0,"imageFlag":0,"evaluationId":0,"evaluationItemId":0}],"paramId":"-2","paramType":-1,"desc":"","type":2,"sameType":2,"encyclopediaId":"","keyItem":1},{"id":1,"name":"城市参考价","paramValues":[{"id":178403,"value":"25.35万","subList":[{"value":"25.35万"},{"value":""}]},{"id":179144,"value":"27.99万","subList":[{"value":"27.99万"},{"value":""}]},{"id":175005,"value":"32.99万","subList":[{"value":"32.99万"},{"value":""}]}],"type":4,"sameType":2,"keyItem":1},{"id":-3,"name":"厂商","paramValues":[{"id":178403,"value":"小米汽车","subList":[{"value":"小米汽车"}],"subListSize":0,"videoFlag":0,"imageFlag":0,"evaluationId":0,"evaluationItemId":0},{"id":179144,"value":"小米汽车","subList":[{"value":"小米汽车"}],"subListSize":0,"videoFlag":0,"imageFlag":0,"evaluationId":0,"evaluationItemId":0},{"id":175005,"value":"小米汽车","subList":[{"value":"小米汽车"}],"subListSize":0,"videoFlag":0,"imageFlag":0,"evaluationId":0,"evaluationItemId":0}],"paramId":"-3","paramType":-1,"desc":"","type":0,"sameType":1,"encyclopediaId":"","keyItem":1},{"id":-4,"name":"级别","paramValues":[{"id":178403,"value":"中大型SUV","subList":[{"value":"中大型SUV"}],"subListSize":0,"videoFlag":0,"imageFlag":0,"evaluationId":0,"evaluationItemId":0},{"id":179144,"value":"中大型SUV","subList":[{"value":"中大型SUV"}],"subListSize":0,"videoFlag":0,"imageFlag":0,"evaluationId":0,"evaluationItemId":0},{"id":175005,"value":"中大型SUV","subList":[{"value":"中大型SUV"}],"subListSize":0,"videoFlag":0,"imageFlag":0,"evaluationId":0,"evaluationItemId":0}],"paramId":"-4","paramType":-1,"desc":"","type":0,"sameType":1,"encyclopediaId":"","keyItem":1},{"id":-5,"name":"能源类型","paramValues":[{"id":178403,"value":"纯电","subList":[{"value":"纯电"}],"subListSize":0,"videoFlag":0,"imageFlag":0,"evaluationId":0,"evaluationItemId":0},{"id":179144,"value":"纯电","subList":[{"value":"纯电"}],"subListSize":0,"videoFlag":0,"imageFlag":0,"evaluationId":0,"evaluationItemId":0},{"id":175005,"value":"纯电","subList":[{"value":"纯电"}],"subListSize":0,"videoFlag":0,"imageFlag":0,"evaluationId":0,"evaluationItemId":0}],"paramId":"-5","paramType":-1,"desc":"","type":0,"sameType":1,"encyclopediaId":"","keyItem":1},{"id":-7,"name":"上市时间","paramValues":[{"id":178403,"value":"2025-06-26","subList":[{"value":"2025-06-26"}],"subListSize":0,"videoFlag":0,"imageFlag":0,"evaluationId":0,"evaluationItemId":0},{"id":179144,"value":"2025-06-26","s ...
# <Response [200]>
